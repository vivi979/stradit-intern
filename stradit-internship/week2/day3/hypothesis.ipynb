# %% [markdown]
# # Real-World Business Hypothesis Tasks

# %%
'''Uber wants to determine whether weekend ride durations differ significantly from weekday rides.'''
import numpy as np
from scipy import stats
# Sample data: ride durations in minutes
weekend_durations = [15, 20, 25, 30, 35, 40, 45]
weekday_durations = [10, 12, 14, 16, 18, 20, 22]
